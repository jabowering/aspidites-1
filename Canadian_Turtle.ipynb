# %%
from NewTurtle import Turtle
t = Turtle()
t.pencolor("red")
t.speed(10)
t.penup()
t.right(90)
t.forward(150)
t.right(90)
t.backward(5)
t.pendown()

t.forward(10)
t.right(100)
t.forward(28)

t.left(120)
t.forward(50)
t.right(125)

t.forward(16)
t.left(35)
t.left(30)
t.forward(50)
t.right(95)
t.forward(18)
t.left(65)
t.forward(20)
t.right(126)
t.forward(20)
t.left(85)
t.forward(18)
t.right(115)
t.forward(45)
t.left(150)
t.forward(70)
t.right(135)
t.forward(31)
t.left(105)
t.forward(35)
t.right(150)
t.forward(35)
t.left(105)
t.forward(31)
t.right(130)
t.forward(70)
t.left(145)
t.forward(45)
t.right(110)
t.forward(18)
t.left(90)
t.forward(20)
t.right(126)
t.forward(20)
t.left(95)
t.forward(17)
t.right(135)
t.forward(70)
t.left(90)
t.forward(16)
t.right(145)
t.forward(50)
t.left(120)
t.forward(28)


t.penup()
t.right(103)
t.forward(120)
t.pendown()
t.left(90)
t.forward(2)
t.right(90)
t.forward(60)
t.right(90)
t.forward(160)
t.right(90)
t.forward(60)
t.right(90)
t.forward(160)
t.left(90)
t.pencolor("white")
t.forward(233)
t.pencolor("red")
t.forward(60)
t.left(90)
t.forward(160)
t.left(90)
t.forward(60)
t.left(90)
t.forward(160)
t.backward(160)
t.pencolor("white")
t.right(90)
t.forward(233)
t.penup()
t.right(90)
t.forward(50)
t.right(90)
t.forward(115)
t.right(2430)
